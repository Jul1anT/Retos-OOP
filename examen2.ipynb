# %% [markdown]
# ## Examen 2- poo unal 2024 - 2 - grupo 4

# %% [markdown]
# **Nombre:**
#
# **Documento:**
#
# **Nota esperada:**

# %% [markdown]
# ### Sección teoría
# En esta sección se presentan 5 preguntas de opción múltiple relacionadas con POO, seleccione una SOLA opción en cada una. Puntaje (10/50).

# %% [markdown]
# 1. ¿Cómo agregar como type hint una clase dentro de si misma?
#     - A. `: Nombre de la clase`
#     - B. No es posible
#     - C. `: "Nombre de la clase"`
#     - D. `: Object`
#
# 2. ¿Cuáles son los dos métodos importantes dentro de un iterador?
#     - A. `next()` y `iter()`
#     - B. `follow` y `iter()`
#     - C. `follow()` y `done()`
#     - D. `next()` y `done()`
#
# 3. ¿Cuál de los pricipios de POO contribuye en mayor medida a la extensibilidad?
#     - A. Abstracción.
#     - B. Polimorfismo
#     - C. Herencia
#     - D. Encapsulamiento
#
# 4. ¿Cuál es el propósito de `self` en una clase de Python?
#     - A. Permite a un objeto referenciar sus propios atributos y métodos desde dentro de la clase
#     - B. Permite a un objeto autoreferenciarse infinitamente
#     - C. Permite aplicar herencia dentro de una clase hija
#     - D. Permite a un objeto pasar información a otros objetos
#
# 5. Una función de orden superior es aquella que solo recibe argumentos tipo función.
#     - A. Verdadero, como en el caso de los closures
#     - B. Falso, porque solo retorna argumentos tipo función.
#     - C. Falso, porque recibe o retorna argumentos tipo función
#     - D. Verdadero, porque todas las funciones son objetos.

# %% [markdown]
# En esta sección coloque sus respuestas:
# 1. <br>
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ### Sección práctica
# En esta sección se desarrollará un solo ejercicio práctico con distintos niveles de complejidad que iran sumando puntaje. (Puntaje 40/50).

# %% [markdown]
# ### Estructura:
#
# Se debe construir la clase `ComplexNumber`.
#
# Genere el diagrama de clases a partir de los métodos definidos a continuación:
#
# + ComplexNumber: Crea un número complejo, se genera a partir de dos argumentos `real_part` e `imaginary_part`.
#
#   - real_part/imaginary_part (atributos): Componentes real e imaginaria del número complejo, son `float`. Son propiedades por tanto, debe implementar un método homonimo que sirva como getter con el decorador `@property` y un setter `@real_part.setter`/`@imaginary_part.setter` que reciban el tipo de dato adecuado.
#
#   - maginude (método): Computa la magnitud o norma del número complejo:
#   $$\text{magnitud} = \sqrt{\text{real\_part}^2 + \text{imaginary\_part}^2}$$
#
#   - phase (método): Computa la fase del número complejo, se puede importar `math`: $$\text{phase} = \arctan\left(\frac{\text{imaginary\_part}}{\text{real\_part}}\right)$$
#
#   - conjugate (método): Retorna el conjugado del número complejo:
#   $$\text{conjugate} = \text{real\_part} - \text{imaginary\_part}i$$
#
#   - is_real (método): Retorna `True` si la parte imaginaria es cerop, `False` en caso contrario.
#
#   - `__add__` (método): Retorna la suma de dos números complejos, se recomienda validar el tipo de objeto que recibe, si es una instancia de `ComplexNumber` (usar `isinstance()`) realizar la operación, en caso contrario levantar una exepción de `TypeError`: $$(a + bi) + (c + di) = (a + c) + (b + d)i$$
#
#   - `__mul__` (método): Retorna el producto de dos números complejos, se recomienda validar el tipo de objeto que recibe, si es una instancia de `ComplexNumber` (usar `isinstance()`) realizar la operación, en caso contrario levantar una exepción de `TypeError`: $$(a + bi) \cdot (c + di) = (ac - bd) + (ad + bc)i$$
#
#   - `__eq__` y `__nq__` (métodos): Comprueba si dos números complejos son iguales o distintos. Se compara parte real con real e imaginaria con imaginaria. Se recomienda validar el tipo de objeto que recibe, si es una instancia de `ComplexNumber` (usar `isinstance()`) realizar la operación, en caso contrario levantar una exepción de `TypeError`.
#
#   - `__lt__`, `__le__`, `__gt__`, `__ge__` (métodos): Valida si las magnitudes de dos números complejos son menor que, menor igual que, mayor que o mayor igual que. Se recomienda validar el tipo de objeto que recibe, si es una instancia de `ComplexNumber` (usar `isinstance()`) realizar la operación, en caso contrario levantar una exepción de `TypeError`.
#
#   - `__str__` (método): Imprimir `f{real_part} + {imaginary_part}i`
#
#   - `__iter__`(método): Retorna una tupla con los `real_part` e `imaginary_part`.
#
#   - `__next__` (método): Retorna primero `real_part` y luego `imaginary_part`.
#
# **Condiciones:**
#  - Se debe validar el tipo de datos ingresados, en caso que no sea el tipo adecuado se debe levantar una excepción `TypeError`.
#  - Es posible usar bucles, condicionales, otras estructuras funcionales.
#  - NO ES POSIBLE USAR MODULOS EXTERNOS a excpeción de los mencionados en la descipción de la clase.
#
# **Rúbicras:**
#  - Diagrama de clases (10/50)
#  - Correcta implementación de los métodos (18/50)
#  - Casos de prueba (12/50)

# %%
# Inserte el codigo de sus clases aqui

# %% [markdown]
# ### Funcionalidad
# Se usara el código generado para las siguientes pruebas (no se tendrán en cuenta respuestas hardcodeadas)

# %% [markdown]
# Prueba suma e igualdad (puntaje 4/50)
# ```python
# c1 = ComplexNumber(3, 4)
# c2 = ComplexNumber(1, 2)
# result_add = c1 + c2 # Esperado ComplexNumber(4, 6)
# print(result_add) # Esperado 4 + 6i
# result_eq = c1 == result_add
# print(result_eq) # Flase
# ```

# %% [markdown]
# Prueba multiplicacion (puntaje 4/50)
# ```python
# c3 = ComplexNumber(3, 4)
# c4 = ComplexNumber(1, 2)
# result_mul = c1 * c2 # Esperado ComplexNumber(-5, 10)
# print(result_mul) # Esperado -5 + 10i
# ```

# %% [markdown]
# Prueba magnitud (puntaje 4/50)
# ```python
# c5 = ComplexNumber(3, 4)
# c6 = ComplexNumber(4, 3)
# magnitude_c5 = c5.magnitude() # Esperado 5
# magnitude_c6 = c6.magnitude() # Esperado 5
# result_comparison = c5 > c6 or c5 <= c6
# print(result_comparison) # Esperado True
# ```
